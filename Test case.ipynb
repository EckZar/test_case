# %% [markdown]
# # 1. Предобработка таблицы

# %% [markdown]
# В качестве основного инструмента для преобразования использовался Python с бибилотекой pandas.
# Все примеры код
#
# Пример преобразованной таблицы можно просмотреть здесь:
#
# https://docs.google.com/spreadsheets/d/1T_27NzkoJFgvejk0TkPyZnXU7CmfYAu4JBmca07wiTo

# %% [markdown]
# # 2. Построить сводную таблицу с разбивкой по месяцам со следующими показателями

# %% [markdown]
# * Количество действующих сотрудников (должностей);
#
# * Количество свободных должностей;
#
# * Доля свободных должностей от итого должностей;

# %% [markdown]
# |Период	| Активные должности | Кол-во позиций | Свободные позиции COUNT | Свободные позиции %|
# |:---------:|:---:|:---:|:--:|:----:|
# |2023.01.01	| 986 | 999 | 13 | 1.30%|
# |2023.02.01 | 975 | 999 | 24 | 2.40%|
# |2023.03.01 | 975 | 999 | 24 | 2.40%|
# |2023.04.01 | 970 | 999 | 29 | 2.90%|
# |2023.05.01 | 983 | 1005 | 22 | 2.19%|

# %% [markdown]
# Ссылка на свод:
#
# https://docs.google.com/spreadsheets/d/1T_27NzkoJFgvejk0TkPyZnXU7CmfYAu4JBmca07wiTo/edit?gid=2121111784#gid=2121111784&range=A1

# %% [markdown]
# # 3. Работа по дополнению предобработанной таблицы, добавьте следующие показатели

# %% [markdown]
# ### 3.1. Федеральные округа и Регионы;

# %% [markdown]
# Полная таблица изменений здесь:
#
# https://docs.google.com/spreadsheets/d/1T_27NzkoJFgvejk0TkPyZnXU7CmfYAu4JBmca07wiTo/edit?gid=547067040#gid=547067040&range=A1

# %% [markdown]
# ### 3.2. Количество месяцев поиска сотрудника по id должности

# %% [markdown]
# |	ID должности	|	Должность	|	Простой в месяцах	|	Город	|
# |:---------:|:---------:|:---------:|:---------:|
# |	1070	|	менеджер	|	4	|	Рузаевка	|
# |	1099	|	начальник отдела	|	4	|	Грязи	|
# |	1104	|	младший специалист	|	4	|	Бор	|
# |	1118	|	управляющий директор	|	4	|	Полевской	|
# |	1145	|	управляющий директор - начальник отдела	|	2	|	Магдагачи	|
# |	1166	|	главный персональный менеджер	|	2	|	Воткинск	|
# |	1184	|	управляющий директор - начальник отдела	|	2	|	Вольск	|
# |	1209	|	директор по работе с состоятельными клиентами	|	2	|	Орск	|
# |	1246	|	главный менеджер по привлечению корпоративных клиентов	|	4	|	Чебаркуль	|
# |	1280	|	заместитель управляющего	|	4	|	Алакуртти	|
# |	1299	|	старший кассир	|	4	|	Забайкальск	|
# |	1300	|	управляющий операционным офисом	|	3	|	Петрозаводск	|
# |	1301	|	управляющий директор - начальник отдела	|	3	|	Нарьян-Мар	|
# |	1302	|	эксперт	|	4	|	Сосновый Бор	|
# |	1330	|	главный кредитный аналитик	|	4	|	Когалым	|
# |	1367	|	главный менеджер по привлечению корпоративных клиентов	|	4	|	Новый Уренгой	|
# |	1370	|	управляющий операционным офисом	|	4	|	Глазов	|
# |	1371	|	директор	|	3	|	Заволжье	|
# |	1372	|	главный специалист	|	4	|	Миасс	|
# |	1373	|	руководитель группы	|	4	|	Красноуфимск	|
# |	1394	|	руководитель группы	|	4	|	Междуреченский	|
# |	1395	|	главный менеджер	|	4	|	Анжеро-Судженск	|
# |	1521	|	старший кассир	|	4	|	Ульяновск	|
# |	1522	|	управляющий операционным офисом	|	1	|	Радужный	|
# |	1523	|	главный кредитный аналитик	|	4	|	Городец	|
# |	1547	|	клиентский менеджер	|	3	|	Барнаул	|
# |	1548	|	эксперт	|	3	|	Забайкальск	|
# |	1549	|	главный кредитный аналитик	|	3	|	Нововоронеж	|
# |	1591	|	клиентский менеджер	|	3	|	Биробиджан	|
# |	1592	|	офис-менеджер	|	3	|	Советский	|
# |	1628	|	главный персональный менеджер	|	1	|	Елабуга	|
# |	1629	|	директор по работе с крупными клиентами	|	2	|	Биробиджан	|
# |	1630	|	управляющий операционным офисом	|	2	|	Лобня	|
# |	1654	|	директор по работе с крупными клиентами	|	2	|	Гусь-Хрустальный	|
# |	1655	|	управляющий операционным офисом	|	2	|	Грозный	|
# |	1656	|	старший кассир	|	1	|	Городец	|
# |	1984	|	заместитель управляющего операционным офисом	|	1	|	Нижний Новгород	|

# %% [markdown]
# ### 3.3. Количество месяцев поиска сотрудника по должности

# %% [markdown]
# |	Должность	|	Простой в месяцах	|
# |:---------:|:---------:|
# |	управляющий операционным офисом	|	12	|
# |	главный кредитный аналитик	|	11	|
# |	старший кассир	|	9	|
# |	главный менеджер по привлечению корпоративных клиентов	|	8	|
# |	руководитель группы	|	8	|
# |	управляющий директор - начальник отдела	|	7	|
# |	эксперт	|	7	|
# |	клиентский менеджер	|	6	|
# |	менеджер	|	4	|
# |	начальник отдела	|	4	|
# |	младший специалист	|	4	|
# |	управляющий директор	|	4	|
# |	заместитель управляющего	|	4	|
# |	главный специалист	|	4	|
# |	главный менеджер	|	4	|
# |	директор по работе с крупными клиентами	|	4	|
# |	главный персональный менеджер	|	3	|
# |	директор	|	3	|
# |	офис-менеджер	|	3	|
# |	директор по работе с состоятельными клиентами	|	2	|
# |	заместитель управляющего операционным офисом	|	1	|

# %% [markdown]
# # 4. Ответьте на следующие вопросы, построив сводные таблицы исходя из дополненных данных пункта 3

# %% [markdown]
# ### 4.1. В каких городах наблюдается нехватка кадров на последний месяц? Сортировка по убыванию;

# %% [markdown]
# |	Город	|	Нехватка	|
# |:-------:|:-------:|
# |	Городец	|	2	|
# |	Биробиджан	|	2	|
# |	Ульяновск	|	1	|
# |	Сосновый Бор	|	1	|
# |	Советский	|	1	|
# |	Новый Уренгой	|	1	|
# |	Нововоронеж	|	1	|
# |	Нижний Новгород	|	1	|
# |	Миасс	|	1	|
# |	Междуреченский	|	1	|
# |	Лобня	|	1	|
# |	Красноуфимск	|	1	|
# |	Когалым	|	1	|
# |	Заволжье	|	1	|
# |	Забайкальск	|	1	|
# |	Гусь-Хрустальный	|	1	|
# |	Грозный	|	1	|
# |	Глазов	|	1	|
# |	Барнаул	|	1	|
# |	Анжеро-Судженск	|	1	|

# %% [markdown]
# ### 4.2. В каком регионе работает наибольшее количество сотрудников на последний месяц? Сортировка по убыванию;

# %% [markdown]
# |	Регион	|	Число сотрудников	|
# |:-------:|:-------:|
# |	Московская обл.	|	56	|
# |	Свердловская обл.	|	50	|
# |	Ханты-Мансийский Автономный округ - Югра	|	36	|
# |	Нижегородская обл.	|	34	|
# |	Мурманская обл.	|	33	|
# |	Саратовская обл.	|	30	|
# |	Ленинградская обл.	|	30	|
# |	Кемеровская область - Кузбасс	|	29	|
# |	Респ. Татарстан	|	28	|
# |	Приморский край	|	28	|
# |	Иркутская обл.	|	28	|
# |	Ямало-Ненецкий АО	|	27	|
# |	Пермский край	|	26	|
# |	Челябинская обл.	|	25	|
# |	Забайкальский край	|	24	|
# |	Амурская обл.	|	24	|
# |	Респ. Саха /Якутия/	|	21	|
# |	Красноярский край	|	21	|
# |	Ставропольский край	|	20	|
# |	г. Санкт-Петербург	|	19	|
# |	Хабаровский край	|	18	|
# |	Самарская обл.	|	18	|
# |	Респ. Башкортостан	|	18	|
# |	Белгородская обл.	|	18	|
# |	Алтайский край	|	18	|
# |	Респ. Коми	|	17	|
# |	Респ. Карелия	|	17	|
# |	Чувашская Республика	|	15	|
# |	Новосибирская обл.	|	15	|
# |	Оренбургская обл.	|	14	|
# |	Калининградская обл.	|	14	|
# |	Тюменская обл.	|	12	|
# |	Владимирская обл.	|	12	|
# |	Калужская обл.	|	11	|
# |	г. Москва	|	10	|
# |	Воронежская обл.	|	9	|
# |	Респ. Удмуртская	|	8	|
# |	Новгородская обл.	|	8	|
# |	Камчатский край	|	8	|
# |	Респ. Мордовия	|	7	|
# |	Респ. Бурятия	|	7	|
# |	Липецкая обл.	|	7	|
# |	Курская обл.	|	7	|
# |	Курганская обл.	|	7	|
# |	Брянская обл.	|	7	|
# |	Сахалинская обл.	|	6	|
# |	Респ. Марий Эл	|	6	|
# |	Кировская обл.	|	6	|
# |	Архангельская обл.	|	6	|
# |		|	6	|
# |	Ульяновская обл.	|	5	|
# |	Респ. Хакасия	|	5	|
# |	Респ. Северная Осетия - Алания	|	5	|
# |	Псковская обл.	|	5	|
# |	Пензенская обл.	|	5	|
# |	Ивановская обл.	|	5	|
# |	Чукотский АО	|	4	|
# |	Томская обл.	|	4	|
# |	Респ. Дагестан	|	4	|
# |	Костромская обл.	|	4	|
# |	Еврейская АО	|	3	|
# |	Респ. Чеченская	|	2	|
# |	Респ. Кабардино-Балкарская	|	2	|
# |	Респ. Алтай	|	2	|
# |	Ненецкий АО	|	2	|
# |	Магаданская обл.	|	2	|
# |	Вологодская обл.	|	2	|
# |	Омская обл.	|	1	|

# %% [markdown]
# ### 4.3. Какие должности подвержены наибольшей текучести. Свод по ID должности.

# %% [markdown]
# ID должности	|	2023.01.01	|	2023.02.01	|	2023.03.01	|	2023.04.01	|	2023.05.01	|	Grand Total	|	Название должности	|	Город	|
# |:-------:|:-------:|:-------:|:-------:|:-------:|:-------:|:-------:|:-------:|:-------:|
# 1523	|	0	|	1	|	1	|	1	|	1	|	4	|	главный кредитный аналитик	|	Городец	|
# 1521	|	0	|	1	|	1	|	1	|	1	|	4	|	старший кассир	|	Ульяновск	|
# 1395	|	0	|	1	|	1	|	1	|	1	|	4	|	главный менеджер	|	Анжеро-Судженск	|
# 1394	|	0	|	1	|	1	|	1	|	1	|	4	|	руководитель группы	|	Междуреченский	|
# 1373	|	0	|	1	|	1	|	1	|	1	|	4	|	руководитель группы	|	Красноуфимск	|
# 1372	|	0	|	1	|	1	|	1	|	1	|	4	|	главный специалист	|	Миасс	|
# 1370	|	0	|	1	|	1	|	1	|	1	|	4	|	управляющий операционным офисом	|	Глазов	|
# 1367	|	0	|	1	|	1	|	1	|	1	|	4	|	главный менеджер по привлечению корпоративных клиентов	|	Новый Уренгой	|
# 1330	|	0	|	1	|	1	|	1	|	1	|	4	|	главный кредитный аналитик	|	Когалым	|
# 1302	|	0	|	1	|	1	|	1	|	1	|	4	|	эксперт	|	Сосновый Бор	|
# 1299	|	1	|	1	|	1	|	1	|	0	|	4	|	старший кассир	|	Забайкальск	|
# 1280	|	1	|	1	|	1	|	1	|	0	|	4	|	заместитель управляющего	|	Алакуртти	|
# 1246	|	1	|	1	|	1	|	1	|	0	|	4	|	главный менеджер по привлечению корпоративных клиентов	|	Чебаркуль	|
# 1118	|	1	|	1	|	1	|	1	|	0	|	4	|	управляющий директор	|	Полевской	|
# 1104	|	1	|	1	|	1	|	1	|	0	|	4	|	младший специалист	|	Бор	|
# 1099	|	1	|	1	|	1	|	1	|	0	|	4	|	начальник отдела	|	Грязи	|
# 1070	|	1	|	1	|	1	|	1	|	0	|	4	|	менеджер	|	Рузаевка	|
# 1592	|	0	|	0	|	1	|	1	|	1	|	3	|	офис-менеджер	|	Советский	|
# 1591	|	0	|	0	|	1	|	1	|	1	|	3	|	клиентский менеджер	|	Биробиджан	|
# 1549	|	0	|	0	|	1	|	1	|	1	|	3	|	главный кредитный аналитик	|	Нововоронеж	|
# 1548	|	0	|	0	|	1	|	1	|	1	|	3	|	эксперт	|	Забайкальск	|
# 1547	|	0	|	0	|	1	|	1	|	1	|	3	|	клиентский менеджер	|	Барнаул	|
# 1371	|	0	|	1	|	1	|	0	|	1	|	3	|	директор	|	Заволжье	|
# 1301	|	1	|	1	|	0	|	1	|	0	|	3	|	управляющий директор - начальник отдела	|	Нарьян-Мар	|
# 1300	|	1	|	0	|	1	|	1	|	0	|	3	|	управляющий операционным офисом	|	Петрозаводск	|
# 1655	|	0	|	0	|	0	|	1	|	1	|	2	|	управляющий операционным офисом	|	Грозный	|
# 1654	|	0	|	0	|	0	|	1	|	1	|	2	|	директор по работе с крупными клиентами	|	Гусь-Хрустальный	|
# 1630	|	0	|	0	|	0	|	1	|	1	|	2	|	управляющий операционным офисом	|	Лобня	|
# 1629	|	0	|	0	|	0	|	1	|	1	|	2	|	директор по работе с крупными клиентами	|	Биробиджан	|
# 1209	|	1	|	1	|	0	|	0	|	0	|	2	|	директор по работе с состоятельными клиентами	|	Орск	|
# 1184	|	1	|	1	|	0	|	0	|	0	|	2	|	управляющий директор - начальник отдела	|	Вольск	|
# 1166	|	1	|	1	|	0	|	0	|	0	|	2	|	главный персональный менеджер	|	Воткинск	|
# 1145	|	1	|	1	|	0	|	0	|	0	|	2	|	управляющий директор - начальник отдела	|	Магдагачи	|
# 1984	|	0	|	0	|	0	|	0	|	1	|	1	|	заместитель управляющего операционным офисом	|	Нижний Новгород	|
# 1656	|	0	|	0	|	0	|	0	|	1	|	1	|	старший кассир	|	Городец	|
# 1628	|	0	|	0	|	0	|	1	|	0	|	1	|	главный персональный менеджер	|	Елабуга	|
# 1522	|	0	|	1	|	0	|	0	|	0	|	1	|	управляющий операционным офисом	|	Радужный	|
# Grand Total	| 13 | 24 | 24 | 29 | 22 | 112 | | |

# %% [markdown]
# ### 4.4. Какие должности подвержены наибольшей текучести. Свод по названию должности.

# %% [markdown]
# |	Должность	|	2023.01.01	|	2023.02.01	|	2023.03.01	|	2023.04.01	|	2023.05.01	|	Grand Total	|
# |:-----:|:-----:|:-----:|:-----:|:-----:|:-----:|:-----:|
# |	управляющий операционным офисом	|	1	|	2	|	2	|	4	|	3	|	12	|
# |	главный кредитный аналитик	|	0	|	2	|	3	|	3	|	3	|	11	|
# |	старший кассир	|	1	|	2	|	2	|	2	|	2	|	9	|
# |	руководитель группы	|	0	|	2	|	2	|	2	|	2	|	8	|
# |	главный менеджер по привлечению корпоративных клиентов	|	1	|	2	|	2	|	2	|	1	|	8	|
# |	эксперт	|	0	|	1	|	2	|	2	|	2	|	7	|
# |	управляющий директор - начальник отдела	|	3	|	3	|	0	|	1	|	0	|	7	|
# |	клиентский менеджер	|	0	|	0	|	2	|	2	|	2	|	6	|
# |	управляющий директор	|	1	|	1	|	1	|	1	|	0	|	4	|
# |	начальник отдела	|	1	|	1	|	1	|	1	|	0	|	4	|
# |	младший специалист	|	1	|	1	|	1	|	1	|	0	|	4	|
# |	менеджер	|	1	|	1	|	1	|	1	|	0	|	4	|
# |	заместитель управляющего	|	1	|	1	|	1	|	1	|	0	|	4	|
# |	директор по работе с крупными клиентами	|	0	|	0	|	0	|	2	|	2	|	4	|
# |	главный специалист	|	0	|	1	|	1	|	1	|	1	|	4	|
# |	главный менеджер	|	0	|	1	|	1	|	1	|	1	|	4	|
# |	офис-менеджер	|	0	|	0	|	1	|	1	|	1	|	3	|
# |	директор	|	0	|	1	|	1	|	0	|	1	|	3	|
# |	главный персональный менеджер	|	1	|	1	|	0	|	1	|	0	|	3	|
# |	директор по работе с состоятельными клиентами	|	1	|	1	|	0	|	0	|	0	|	2	|
# |	заместитель управляющего операционным офисом	|	0	|	0	|	0	|	0	|	1	|	1	|
# |	Grand Total	|	13	|	24	|	24	|	29	|	22	|	112	|

# %% [markdown]
# # 5. Визуализация (тип диаграммы и библиотека на ваше усмотрение);

# %% [markdown]
# ### 5.1. Количество действующих сотрудников по Федеральным округам;

# %%
import matplotlib.pyplot as plt

x = [815, 770, 745, 1130, 740, 170, 625]
y = ['УФО', 'СЗФО', 'ЦФО', 'ПФО', 'ДФО', 'СКФО', 'СФО']

plt.bar(y, x)
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# ### 5.2. Количество свободных должностей по регионам.

# %%
i = [32, 11, 32, 14, 14, 7, 2]
j = ['ПФО', 'ЦФО', 'УФО', 'ДФО', 'СЗФО', 'СФО', 'СКФО']

plt.bar(j, i)
# Out:
# <BarContainer object of 7 artists>
